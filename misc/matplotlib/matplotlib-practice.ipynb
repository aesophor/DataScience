# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y1 = [1, 4, 9]
y2 = [10, 5, 8]
plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(['dafuq'])
plt.show()
