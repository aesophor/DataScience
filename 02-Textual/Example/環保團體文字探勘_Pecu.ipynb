# %%
import re
import time
import io
import os
import json
import pickle
import pandas as pd
from optparse import OptionParser
from pandas import DataFrame, read_csv

path='./data/'

# %%
with open('allData.pkl', 'rb') as f:
     allData = pickle.load(f)
        
allData
# Out:
#       docClass          classID className  \
# 0           環保  148513668543221   地球公民基金會
# 1           環保  148513668543221   地球公民基金會
# 2           環保  148513668543221   地球公民基金會
# 3           環保  148513668543221   地球公民基金會
# 4           環保  148513668543221   地球公民基金會
# 5           環保  148513668543221   地球公民基金會
# 6           環保  148513668543221   地球公民基金會
# 7           環保  148513668543221   地球公民基金會
# 8           環保  148513668543221   地球公民基金會
# 9           環保  148513668543221   地球公民基金會
# 10          環保  148513668543221   地球公民基金會
# 11          環保  148513668543221   地球公民基金會
# 12          環保  148513668543221   地球公民基金會
# 13          環保  148513668543221   地球公民基金會
# 14          環保  148513668543221   地球公民基金會
# 15          環保  148513668543221   地球公民基金會
# 16          環保  148513668543221   地球公民基金會
# 17          環保  148513668543221   地球公民基金會
# 18          環保  148513668543221   地球公民基金會
# 19          環保  148513668543221   地球公民基金會
# 20          環保  148513668543221   地球公民基金會
# 21          環保  148513668543221   地球公民基金會
# 22          環保  148513668543221   地球公民基金會
# 23          環保  148513668543221   地球公民基金會
# 24          環保  148513668543221   地球公民基金會
# 25          環保  148513668543221   地球公民基金會
# 26          環保  148513668543221   地球公民基金會
# 27          環保  148513668543221   地球公民基金會
# 28          環保  148513668543221   地球公民基金會
# 29          環保  148513668543221   地球公民基金會
# ...        ...              ...       ...
# 54512       環保  148513668543221   地球公民基金會
# 54513       環保  148513668543221   地球公民基金會
# 54514       環保  148513668543221   地球公民基金會
# 54515       環保  148513668543221   地球公民基金會
# 54516       環保  148513668543221   地球公民基金會
# 54517       環保  148513668543221   地球公民基金會
# 54518       環保  148513668543221   地球公民基金會
# 54519       環保  148513668543221   地球公民基金會
# 54520       環保  148513668543221   地球公民基金會
# 54521       環保  148513668543221   地球公民基金會
# 54522       環保  148513668543221   地球公民基金會
# 54523       環保  148513668543221   地球公民基金會
# 54524       環保  148513668543221   地球公民基金會
# 54525       環保  148513668543221   地球公民基金會
# 54526       環保  148513668543221   地球公民基金會
# 54527       環保  148513668543221   地球公民基金會
# 54528       環保  148513668543221   地球公民基金會
# 54529       環保  148513668543221   地球公民基金會
# 54530       環保  148513668543221   地球公民基金會
# 54531       環保  148513668543221   地球公民基金會
# 54532       環保  148513668543221   地球公民基金會
# 54533       環保  148513668543221   地球公民基金會
# 54534       環保  148513668543221   地球公民基金會
# 54535       環保  148513668543221   地球公民基金會
# 54536       環保  148513668543221   地球公民基金會
# 54537       環保  148513668543221   地球公民基金會
# 54538       環保  148513668543221   地球公民基金會
# 54539       環保  148513668543221   地球公民基金會
# 54540       環保  148513668543221   地球公民基金會
# 54541       環保  148513668543221   地球公民基金會
#
#                                        docTitle  \
# 0                  "【12/26 為下一代而走 反空污、抗暖化大遊行】\n
# 1         "【高雄講座】12/4 跨國之鏡—韓國環境運動聯合參訪分享會（吳如媚）\n
# 2                    "【滿口仁義道德、卻一肚子OOXX的農委會！】 \n
# 3                   "【九月農地悲歌！農舍修法轉彎、違章工廠就地合法】\n
# 4                     "【好山好水好政治—地球公民政治參與原則說明】\n
# 5                     "【核三重啟，要回到原點？還是加速能源改革？】\n
# 6                                "【保護黑琵、人鳥共存】\n
# 7             "【 Earth Day Taiwan 地球的事就是我們的事】\n
# 8                          "【環境敏感區與礦場的結該如何解?】\n
# 9                                  "【東海岸要喘息！】\n
# 10                         "什麼是禁食？林義雄禁食背後的故事？\n
# 11                  "【倡議五年，化學物質專責管理機關終於誕生！��】\n
# 12                  "【紫爆連連 政府不作為  我們要戴口罩睡覺嗎？】\n
# 13                           "【礦業制度的改變，決戰明天！】\n
# 14             "【高雄】8/31 日頭正夯 全民發電--太陽能光電推廣講座\n
# 15                                     "《德國綠能革命
# 16                                    "今天上午十點\n
# 17                         "【3/27後災難 工程倫理工作坊】\n
# 18                         "【312廢核大遊行，一起站出來！】\n
# 19                        "【中油關廠承諾跳票 還在呼攏後勁人】\n
# 20     "【看電影】《給親愛的孩子》投寄給未來的世代的家書，台灣百年山林開拓史紀錄片\n
# 21            "【高雄講座】11/20俠客與良師的蛻變之路（詹順貴+李根政）\n
# 22                   "【東海岸開發不曾停歇，《太陽的孩子》真實上演】\n
# 23                              "【又偷排 ！嗚咽後勁溪】\n
# 24                              "【愛地球，從擦屁屁開始】\n
# 25                       "【國土重大關鍵課題---全國區域計畫】\n
# 26                "【給青少年一張世代正義的門票：投票正義，十八開始！】\n
# 27                                "【為台灣添些色彩吧】\n
# 28                      "【告急！捐助地球公民，成為我們的靠山！】\n
# 29                       "【循環經濟是什麼？】廢棄物變身成黃金 \n
# ...                                         ...
# 54512                 "【終於等到這天！中油高雄煉油廠下個月遷離！】\n
# 54513                           "【高雄講座】低碳生活系列\n
# 54514                          "【空污嚴重，新內閣踹共！】\n
# 54515                               "【講座地點變更】\n
# 54516            "請廣發連署：http://chn.ge/1jB2HyF\n
# 54517                      "【募一個守護山海的人】DAY 08\n
# 54518                     "【眾志成城】停止東海岸大型開發審查！\n
# 54519                      "【報告新科立委，我家隔壁會爆炸！】\n
# 54520                        "【小小公民能盡的最微薄的力量】\n
# 54521                           "【造林？造到那裡去了！】\n
# 54522                            "【台灣的發展由誰決定】\n
# 54523                  "【合作綠學堂：6/21伸進農村的開發怪手】\n
# 54524                          "【好sweet的一筆捐款】\n
# 54525                      "【2017寒假營隊】在南方的土地上\n
# 54526                    "【好片推薦】明日進行曲Tomorrow\n
# 54527                     "【今晚十點，公共電視：再見！煉油廠】\n
# 54528             "【核電影】12/12 破天而降的核電廠@美濃文創中心\n
# 54529                        "【日本輸台食品 須附產地證明】\n
# 54530                               "【送綠電進偏鄉】\n
# 54531                             "【我們的島─捍山】 \n
# 54532                         "【整整石化！看穿FTA幻術】\n
# 54533                            "【集氣，美麗灣拆拆拆】\n
# 54534                              "【地球公民撐香港】\n
# 54535                                 "【報名額滿】\n
# 54536                   "【講座 7/5 棄民與隱蔽，現在的福島】\n
# 54537                     "【經濟部的日月光條款恐罰不到日月光】\n
# 54538                  "【台北講座】12/8農地不農用 糧食哪裡來\n
# 54539                      "【高雄】11/12能源與我們的生活\n
# 54540         "6/10 巡演首場【脫口罩！找藍天影像行動計劃】@高雄塩旅社\n
# 54541                       "【東海岸快炒：炒地炒樓炒黃金！】\n
#
#                                                     docs
# 0      今天 早上 ， 我們 與 台灣 健康 空氣 行動 聯盟 的 夥伴 一起 到 總統府 前開 記...
# 1      你 知道 東亞 最大 的 環境 組織 是 誰 嗎 ？ 超過 五十個 分支 的 韓國 環境 運...
# 2      今天 區委 會 的 第次 大會 ， 審議 全國 區域 計畫 修正案 草案 的 環境 敏感區 ...
# 3      白米 炸彈 客 的 電影 情節 真實 上演 ， 今天 宜蘭縣 部份 農會 與 房地 仲介 相...
# 4      政治 ， 對 你 而言 是 什麼 ？ 當你 在 關注 地球 公民 基金會 ， 看見 我們 陸...
# 5      核三 失火 ， 全台 備轉 容量 降低 ， 為 了 避免 限電 危機 ， 昨日 原能 會 已...
# 6      今日 鳥類 、 明日 人類 。 保護 其他 生命 ， 人類 才 得以 健康 地 存活 下去 ...
# 7      台北 地球日 已 邁入 第八年 ， 今明兩天 在 臺灣 博物館 的 綠色 市集 ， 地球 公...
# 8      環境 敏感區 採礦 擴張 再 一起 ！ 向陽 礦業 ， 主要 生產 雲母 礦 開採區 除了 ...
# 9      把關 機制 應 建立 ， 大型 開發 全面 退出 花 東海岸 內政部 營建 署 預計 從 月...
# 10     遇到 不 知道 的 朋友 問起 時 ， 歡迎 下載 這份 文宣給 他 喔 ！ 林義雄 無 單...
# 11     能 想像 嗎 ？ 全 台灣 使用 的 化學物質 超過 萬種 ， 但 列管 的 毒化 物 卻 ...
# 12     中南部 月 空污 紫爆 連連 ， 環保署 今天 舉辦 空氣 品質 嚴重 惡化 緊急 防制 辦...
# 13     礦區 居民 期盼 數十年 的 礦業 制度 改革 ， 竟 在 經濟部 發出 礦業 不 需要 政...
# 14     民眾 可以 怎麼 參與 能源 轉型 呢 ～ 轉型 再生能源 已 是 國際 共同 趨勢 ， 陽...
# 15     德國 的 綠能 革命 是 一場 豪賭 嗎 ？ 在 意識 到 我們 無法 承擔 核能 發電所 ...
# 16     行政院 門口 讓 我們 與 土地 土地 上 的 人們 站 在一起 捍衛 台灣 山海 的 決心...
# 17     台灣 工學院 約 有 的 學生 修過 工程 倫理 ， 但是 ， 工程 倫理 適當 的 教學內...
# 18     今天 ， 核一廠 二號機 驚傳 跳機 ， 老舊 核電廠 故障 頻傳 ， 核三廠 更是 直接 ...
# 19     再 二天 就 過年 了 ， 後勁 人 的 新年 希望 許了 年 ， 卻 被 玩弄 了 年 。...
# 20     年 莫 拉克 颱風 ， 簡秀芽 在 梅山 鄉 的 老家 被 土石 流 沖走 ， 但 奇蹟 地...
# 21     詹順貴 ， 環境 法律 人 協會 理事長 ， 也 是 地球 公民 基金會 董事 。 李根政 ...
# 22     今晚 ， 基 翬 部落 族人 已經 千里迢迢 從 三 仙台 地區 來到 台北 ， 明天 上午...
# 23     近日 又 查獲 後勁 溪 被 偷排 強酸 廢水 ， 排放口 水樣 測得 值僅 。 日 月光 ...
# 24          地球日 ， 愛 地球 的 妳 你 可以 再生 衛生紙 使用 心得 篇 地球 公民 基金會
# 25     長久以來 ， 山坡地 開發 、 工業污染 、 農地 流失 、 都市計畫 浮濫 徵收 等 亂象...
# 26     今天下午 ， 馬政府 執政 甫 滿 六周年 ， 台少盟 號召 四十多個 關注 青少年 合理 ...
# 27     稍縱即逝 地 彩虹 ， 在 午後 大雨 中 的 台北盆地 現身 。 從 地球 公民 北辦 九...
# 28     地球 公民 基金會 ， 正 面臨 財務危機 ， 亟需 您 的 捐助 。 截至 十月底 ， 我...
# 29     馬上 報名 轉變 以往 線性 思考 產業 模式 ， 提供 可 抽換 相機 的 手機 ， 打造...
# ...                                                  ...
# 54512  今晚 八點 ， 地球 公民 王敏玲 副 執行長 受邀 上公視 有話好說 ， 歡迎 準時 收看...
# 54513  本 周五 起 ， 實踐 低碳 生活 的 方式 分享 即將 開始 將從 企業 與 社區 的 角...
# 54514  中南部 空污 嚴重 ， 地球 公民 發起 校園 空污旗 活動 示警 ， 參與 活動 的 高雄...
# 54515  因為 報名 人數 踴躍 ， 故 今晚 的 講座 地點 移至 花蓮市 國興 里 碧雲 莊 活動...
# 54516  林義雄 先生 以 禁食 行動 對 政府 提出 停建 核四 的 呼籲 ， 以 自身 生命 堅決...
# 54517  圖片 裡的 地方 ， 過去 叫做 基 翬 海岸 ， 現在 是 滿地 富 遊樂區 。 十 公頃...
# 54518  繼 美麗 灣 撤銷 環評 許可 定 讞 後 ， 又 傳出 東海岸 兩個 開發 案 都蘭 鼻 ...
# 54519  今日 清晨 ， 位於 台 中 大肚 的 興農 化工廠 發生爆炸 ， 造成 一名 員工 殉職 ...
# 54520  我 是 一個 設計者 ， 設計 許多 跟 反核 、 社會 議題 相關 的 商品 。 透過 義...
# 54521  荒謬 在 原本 就是 森林 的 保安 地 ， 噴 除草劑 、 清除 瀕危 原生 小苗 ， 在...
# 54522  地球 公民 董事 杜文苓 與 研究員 林心 乙 接受 的 專訪 ， 從 自身 人生 經驗 出...
# 54523  報名 活動 網頁 工業 發展 ， 汙染 留 農地 ， 再 透過 飲食 回到 我們 的 餐桌 ...
# 54524  來自 花 ㄌ ㄧ ㄢ ˊ ㄒ ㄧ ㄢ ˋ ㄈ ㄨ ˋ ㄩ ㄢ ˊ ㄍ ㄨ ㄛ ˊ 小 一年 ...
# 54525  在 高雄 生長 的 你 對 這片 土地 認識 多少 呢 ？ 走出 課本 ， 腳踏實地 認識 ...
# 54526  許 一個 不 受 化石 燃料 控制 的 未來 ， 地球 的 公民 們 已 開始 行動 ！ 日...
# 54527  自年 中油 進駐 半屏山 腳下 ， 後勁 人 便 陷入 面對 爆炸 的 危險 中 ， 空氣 ...
# 54528  破天 而 降 的 核電廠 是 紀錄 法國 、 美國 強行 推銷 核電廠 到 印度 ， 並 打...
# 54529  針對 是否 要 放寬 日本 輻射 食品 輸台 管制 ， 昨天 立法院 朝野 協商 結果 ， ...
# 54530  政府 不給 部落 用電 ， 但 高階 、 低階 核廢料 的 最終 處置 場 ， 卻 通通 鎖...
# 54531  兩周前 ， 好多 朋友 一塊 與 我們 到 了 花蓮 太魯閣 ， 一起 參與 反亞泥 ， 捍...
# 54532  中 韓 宣布 一致 後 ， 台灣 五大 石化 家族 哭喊 失去 競爭力 ， 快簽 兩岸 貨貿...
# 54533  今天下午 ， 高雄 高等 行政法院 即將 宣判 年底 的 那場 醜陋 的 美麗 灣 環評 是...
# 54534  民主 ， 從來 都 是 任何人 所 希望 追求 的 。 當有 限制 的 假 普選 ， 無法 ...
# 54535  感謝 各位朋友 的 踴躍 報名 ， 目前 報名 人數 已額 滿 ， 想 參加 的 朋友 請 ...
# 54536  為 了 孩子 的 健康 ， 搬離 受 核災 汙染 的 日本 。 福島 媽媽 昌子 女士 帶著...
# 54537  經濟部 擬修 日 月光 條款 一家 公司 同一 事件 連續 違規 且 情節 重大 ， 在 年...
# 54538  立即 報名 台灣 號稱 有 萬公頃 農地 ， 但 實際 的 可耕地 卻 遠遠 低於 這個 數...
# 54539  立即 報名 按下 開關 就 有 的 電力系統 、 加滿 油 就 能 移動 的 交通工具 ， ...
# 54540  有組 中南部 導演 ， 拍攝 部 以上 找 藍天 計畫 短片 ， 將在 全台 進行 場 巡演...
# 54541  記得 去年 的 都蘭 灣 最大 開發 案杉原 棕櫚 濱海 渡假村 嗎 這次 的 黃金 海 休...
#
# [54542 rows x 5 columns]

# %%
mergeData = allData.groupby(['docClass', 'className'])['docs'].apply(' '.join).reset_index()
mergeData
# Out:
#    docClass                                          className  \
# 0        動物                                             "HOTAC
# 1        動物                                          "愛貓協會(NGO
# 2        動物                                      APA中華民國保護動物協會
# 3        動物                                        Rose的流浪動物花園
# 4        動物                             Taiwan SPCA 台灣防止虐待動物協會
# 5        動物                                      g0v.tw 台灣零時政府
# 6        動物                                        古都保存再生文教基金會
# 7        動物                                         台北鳥會野鳥救傷中心
# 8        動物                                      台北鳥會關渡自然公園管理處
# 9        動物                                        台南市關懷流浪動物協會
# 10       動物  台灣公立收容所非官方認養資訊*the Unofficial Adoption info of...
# 11       動物                                         台灣動物不再流浪協會
# 12       動物                                          台灣動物保護協進會
# 13       動物                                       台灣動物保護行政監督聯盟
# 14       動物                                     台灣動物平權促進會 TAEA
# 15       動物                                          台灣動物社會研究會
# 16       動物                                             台灣愛兔協會
# 17       動物                                          台灣流浪兔保護協會
# 18       動物                            台灣認養地圖 meetpets @Taiwan
# 19       動物                                           台灣黑熊保育協會
# 20       動物                                              奶貓救援隊
# 21       動物                                          小卡貓狗救援志工團
# 22       動物                                            幸福狗流浪中途
# 23       動物                                          張媽媽流浪動物之家
# 24       動物                                         彰化員林流浪犬收容所
# 25       動物                                     新竹流浪動物收容所照片公告區
# 26       動物                           流浪狗不是廢棄物 不應由清潔隊捕捉(廢除安樂死)
# 27       動物                                           照生會貓狗119
# 28       動物                                       狗腳印幸福聯盟 TPKR
# 29       動物                                     社團法人中華親善動物保護協會
# 30       動物                                    社團法人台南市流浪動物愛護協會
# 31       動物                                            臺北市動物之家
# 32       動物                                  臺北市流浪貓保護協會-民間動保團體
# 33       動物                     臺灣流浪動物認養 Home For Stray Taiwan
# 34       動物                                        請支持流浪貓TNR計劃
# 35       動物                                  貓狗同樂會（台灣收容動物關懷協會）
# 36       動物                                      財團法人流浪動物之家基金會
# 37       動物                                        高雄市流浪動物保育協會
# 38       動物                                        高雄市關懷流浪動物協會
# 39       環保                             Greenpeace 綠色和平 (台灣網站)
# 40       環保                    Wild at Heart Taiwan 台灣蠻野心足生態協會
# 41       環保                                        主婦聯盟環境保護基金會
# 42       環保                                        主婦聯盟生活消費合作社
# 43       環保                                           全國廢核行動平台
# 44       環保                                          南台灣廢核行動聯盟
# 45       環保                                               反核部隊
# 46       環保                        台灣世界展望會 World Vision Taiwan
# 47       環保  台灣環境資訊協會 Taiwan Environmental Information Asso...
# 48       環保                                             台灣農村陣線
# 49       環保                                              台灣農業讚
# 50       環保                                       善耕-關懷台灣文教基金會
# 51       環保                                            地球公民基金會
# 52       環保                                          媽媽監督核電廠聯盟
# 53       環保                                           我是人，我反核！
# 54       環保                      激進工作室 - Radicalization Studio
# 55       環保                                             環境資訊中心
# 56       環保                                             荒野保護協會
#
#                                                  docs
# 0   非常 直白 ， 非常 感慨 ， 也 讓 人 有 更深 的 省思 更 多 的 卻是 對 制度 ...
# 1   敬請 轉貼 歡迎 參觀 暫停 送養會 一次 ， 洽談 認養 及 預約 一般 日 晚上 時間 ...
# 2   關心 流浪 動物 的 朋友 們 ， 最 擔心 的 就是 汪 喵 棄養 的 問題 ， 告訴您 ...
# 3   這是 一個 悲傷 的 故事 ， 我們 期待 它 有 個 溫暖 的 結局 兩隻 在 實驗室 過...
# 4   剛才 沒有 看到 李奧納多 紀錄片 的 朋友 可以 到 這邊 線上 觀看 ！ 李奧納多 前往...
# 5   報導 者 是 台灣 少數 非營利 網路 媒體 之一 ， 總主筆 李雪莉 也 受邀 擔任 本屆...
# 6   謝謝 各位 夥伴 過去 的 支持 年 也 請 多多指教 古都 的 策略 是 台南市 政府 將...
# 7   兩日 台北 鳥會 救傷 中心 沒有 營業 ， 若要 送傷 鳥 到 義診 醫院 也 記得 先 ...
# 8   申請 截止日 延長 至 年月日 止年 關渡 國際 自然 藝術 季 來自 真實 的 故事 徵求...
# 9   送養 報名 開始 囉 手邊 有犬貓 待 送 的 民眾 請 別錯過 了 ！ 報名 方式 請 詳...
# 10  進所 日期 年月日 捕獲 鄉鎮 市西 港區 東 竹林 近 後 營區 產業 道路 進所 原因 ...
# 11  我們 需要 台北 到 荷蘭 阿姆斯特丹 荷航 直飛 的 旅客 幫 我們 帶狗 。 文件 我們...
# 12  為 了 保育 場的 同伴 們 拼 了 ！ 寵物 展 還有 最後 一天 哦 協會 的 攤位 在...
# 13  劉邦 祺 說 ， 學校 師生 、 家長 常會 捐出 二手物品 ， 利用 校慶 或 其他 活動...
# 14  小浪童 寒夜 連鞋 都 沒有 唯一 寶貴 長袖 毛衣 讓給 夥伴 小黃狗 ️ 原來 ， 相依...
# 15  這周 末 ， 在 台 中 。 大人 、 小孩 一 起來 參與 海洋 影像 饗宴 。 ◆ 六 ...
# 16  尬 車哥 的 絡腮鬍 造型 ， 夠潮 吧 褓 姆 潮 男 ， 讓 小 的 幫 你 擦 嘴巴 ...
# 17  冰冰 聽得懂 自己 的 名字 耶 ！ 很 聰明 吧 ！ 小編 覺得 中途 麻好 用心 喔 ，...
# 18  原訂 日 下午 在 光點 舉辦 的 吉貓 認養 相親會 因 連日 低溫 下雨 的 天氣 考量...
# 19  好消息 與 越南 傳統 中藥 協會 簽訂 了 一個 重要 的 協議 ， 中藥 協會 承諾 將...
# 20  通報 人 送醫 檢查 了 目前 自行 照顧 若 需要 中途 幫忙 會 再 發文 嘉義 水上 ...
# 21  感恩 您 的 支持 與 肯定 讓 我們 有 能力 繼續 拯救 更 多 需要 幫助 的 毛孩子...
# 22  訂單 有 些許 出錯 無法 如期 收貨 的 朋友 不要 罵 得 太 用力 ～ 他們 會 很 ...
# 23  磨練 一個 人 的 耐性 ， 磨練 一個 人 的 孤獨 。 磨練 一個 人 的 恆心 ， 磨...
# 24  請 多 參考 認領 養 平台 上 資訊 想 知道 收容所 內有 哪些 毛 小孩 嗎 ？ 只要...
# 25  一張 照片 ， 想 帶來 什麼 ？ 是 一萬個 讚 ， 還是 一個 生命 的 改變 ？ 南 ...
# 26  ＊ 米克斯 ＊ 母 ＊ 皆 已 結紮 ＊ 目前 約 七個 月 大 個性 溫馴 親人 又 撒嬌...
# 27  請 大家 在 打 發票 時 ， 請 告訴 便利商店 店員 ， 我要 捐 愛心 碼 ， 照生 ...
# 28  住 在 的 ， 加油 啊 如果 你 還不 認識 ， 請 透過 狗 腳印 年桌 曆 與 她 相...
# 29  這 八個 孩子 這麼 小 就 被 帶進 收容所 ， 我們 不 知道 他們 的 媽媽 在 哪裡...
# 30  這 一次 的 案件 並 不是 車禍 ， 而是 傳染 率極 高 的 菜花 腫瘤 ， 照片 中 ...
# 31  編號 籠號 性別 男生 年紀 歲 花色 黃 虎 斑進 所 日期 收容 編號 原為 動保 案件...
# 32  又 去 找 美容師 挖 寶 黃金寶 送養 中項 錬 太小 條 ， 不 小心 就 會 被 毛 ...
# 33  寒冷 的 冬天 這些 流浪 動物 們 需要 您 的 幫忙 ！ ！ 台灣 貓狗 聯合 勸募 平...
# 34  適當 的 高度 ， 可 減少 貓咪 嘔吐 機會 ， 超 完美 碗 架 ， 多項 獨特 的 功...
# 35  貓桌 曆 貓咪 悄悄 說 ， 認養 爸媽 們 寫下 了 想 對貓 寶貝 說 的 悄悄話 ， ...
# 36  凡 購買 愛心 大使 張祖誠台 中場 演唱會 門票 一張 ， 浪浪 就 有 柏萊富 飼 天然...
# 37  小黑 是 典型 浪孩 的 悲歌 先 被遺棄 ， 再 被捕 獸 夾夾壞 腳 ， 又 差點 被 ...
# 38  搶救 六龜 斷腳 狗 及 小 孤兒 年月日 上午 ， 協會 救援隊 前往 高雄市 六龜 區 ...
# 39  來點 負 能量 減法 生活 瞭解 更 多 減法 生活 月 日 ， 南極 海洋生物 資源 養護...
# 40  為 了 捷運 新莊 機廠 開發 ， 樂生 院所 在 的 山坡 被 挖掉 了 一大半 一個 面...
# 41  經濟 民主 連合 研究員 許博任 經民連 在 就 曾經 發表聲明 ， 針對 輻射 食品 進口...
# 42  看似 平凡 的 材料 ， 經過 另外 一種 做法 就 會 有 耳目一新 的 感受 ， 白 肉...
# 43  零 核電 期間 ， 日本 進口 昂貴 的 液化 天然氣 量 創下 新高 ， 安倍 和 大多數...
# 44  年 夏季 北極 冰層 將 全部 融化 ， 失去 這天 然 空調 ， 地球 會 變成 什麼 樣...
# 45  朝日新聞 日本 原子力 規制 委員會 指示 東京 電力公司 停止 在 福島 核電廠 鎔 毀的...
# 46  對 台灣 偏鄉 的 弱勢 家庭 來說 ， 由於 就醫 不如 城市 方便 ， 加上 經濟 拮据...
# 47  迎接 年 前夕 ， 本會 再度 推出 年度 鉅 獻 十大 環境 新聞 ， 讓 所有 支持 環...
# 48  這期 的 季刊 文章 ， 環繞 著 一個 與 農友 、 消費者 都 切身 相關 的 主題 極...
# 49  人類 也 是 地球 物種 之一 ， 人類 當然 也 該 為 物種 消失 負起 責任 ， 追 ...
# 50  希望 多年 後 我們 看起來 也 像 濤 哥 一樣 永 。 保 。 年 。 輕健 ． 康 ．...
# 51  今天 早上 ， 我們 與 台灣 健康 空氣 行動 聯盟 的 夥伴 一起 到 總統府 前開 記...
# 52  屋頂 是 城市 的 另 一張 臉 。 從 空中 俯瞰 ， 台灣 都會區 的 屋頂 幾乎 都 ...
# 53  地震 後 ， 為 存放 受 輻射 汙染 的 地下水 ， 福島 第一 核電廠 開始 興建 密密...
# 54  內地 搖滾 活動 專賣 ， 為 台灣 加油 ！ 馬 上點 入 進行 募資 購票 小心 安全 ...
# 55  看到 了 生態 的 美好 ， 因而 想要 讓 更 多 人 看到 這樣 美好 的 景色 。 然...
# 56  你 曾經 深受 荒野 的 自然 講座 感動 嗎 ？ 那 一幅幅 動人 的 風景 、 有趣 的...

# %%
mergeData['docClass'][mergeData['docClass'] == "動物"] = 'animal'
mergeData['docClass'][mergeData['docClass'] == "環保"] = 'environment'

mergeData
# Out:
#        docClass                                          className  \
# 0        animal                                             "HOTAC
# 1        animal                                          "愛貓協會(NGO
# 2        animal                                      APA中華民國保護動物協會
# 3        animal                                        Rose的流浪動物花園
# 4        animal                             Taiwan SPCA 台灣防止虐待動物協會
# 5        animal                                      g0v.tw 台灣零時政府
# 6        animal                                        古都保存再生文教基金會
# 7        animal                                         台北鳥會野鳥救傷中心
# 8        animal                                      台北鳥會關渡自然公園管理處
# 9        animal                                        台南市關懷流浪動物協會
# 10       animal  台灣公立收容所非官方認養資訊*the Unofficial Adoption info of...
# 11       animal                                         台灣動物不再流浪協會
# 12       animal                                          台灣動物保護協進會
# 13       animal                                       台灣動物保護行政監督聯盟
# 14       animal                                     台灣動物平權促進會 TAEA
# 15       animal                                          台灣動物社會研究會
# 16       animal                                             台灣愛兔協會
# 17       animal                                          台灣流浪兔保護協會
# 18       animal                            台灣認養地圖 meetpets @Taiwan
# 19       animal                                           台灣黑熊保育協會
# 20       animal                                              奶貓救援隊
# 21       animal                                          小卡貓狗救援志工團
# 22       animal                                            幸福狗流浪中途
# 23       animal                                          張媽媽流浪動物之家
# 24       animal                                         彰化員林流浪犬收容所
# 25       animal                                     新竹流浪動物收容所照片公告區
# 26       animal                           流浪狗不是廢棄物 不應由清潔隊捕捉(廢除安樂死)
# 27       animal                                           照生會貓狗119
# 28       animal                                       狗腳印幸福聯盟 TPKR
# 29       animal                                     社團法人中華親善動物保護協會
# 30       animal                                    社團法人台南市流浪動物愛護協會
# 31       animal                                            臺北市動物之家
# 32       animal                                  臺北市流浪貓保護協會-民間動保團體
# 33       animal                     臺灣流浪動物認養 Home For Stray Taiwan
# 34       animal                                        請支持流浪貓TNR計劃
# 35       animal                                  貓狗同樂會（台灣收容動物關懷協會）
# 36       animal                                      財團法人流浪動物之家基金會
# 37       animal                                        高雄市流浪動物保育協會
# 38       animal                                        高雄市關懷流浪動物協會
# 39  environment                             Greenpeace 綠色和平 (台灣網站)
# 40  environment                    Wild at Heart Taiwan 台灣蠻野心足生態協會
# 41  environment                                        主婦聯盟環境保護基金會
# 42  environment                                        主婦聯盟生活消費合作社
# 43  environment                                           全國廢核行動平台
# 44  environment                                          南台灣廢核行動聯盟
# 45  environment                                               反核部隊
# 46  environment                        台灣世界展望會 World Vision Taiwan
# 47  environment  台灣環境資訊協會 Taiwan Environmental Information Asso...
# 48  environment                                             台灣農村陣線
# 49  environment                                              台灣農業讚
# 50  environment                                       善耕-關懷台灣文教基金會
# 51  environment                                            地球公民基金會
# 52  environment                                          媽媽監督核電廠聯盟
# 53  environment                                           我是人，我反核！
# 54  environment                      激進工作室 - Radicalization Studio
# 55  environment                                             環境資訊中心
# 56  environment                                             荒野保護協會
#
#                                                  docs
# 0   非常 直白 ， 非常 感慨 ， 也 讓 人 有 更深 的 省思 更 多 的 卻是 對 制度 ...
# 1   敬請 轉貼 歡迎 參觀 暫停 送養會 一次 ， 洽談 認養 及 預約 一般 日 晚上 時間 ...
# 2   關心 流浪 動物 的 朋友 們 ， 最 擔心 的 就是 汪 喵 棄養 的 問題 ， 告訴您 ...
# 3   這是 一個 悲傷 的 故事 ， 我們 期待 它 有 個 溫暖 的 結局 兩隻 在 實驗室 過...
# 4   剛才 沒有 看到 李奧納多 紀錄片 的 朋友 可以 到 這邊 線上 觀看 ！ 李奧納多 前往...
# 5   報導 者 是 台灣 少數 非營利 網路 媒體 之一 ， 總主筆 李雪莉 也 受邀 擔任 本屆...
# 6   謝謝 各位 夥伴 過去 的 支持 年 也 請 多多指教 古都 的 策略 是 台南市 政府 將...
# 7   兩日 台北 鳥會 救傷 中心 沒有 營業 ， 若要 送傷 鳥 到 義診 醫院 也 記得 先 ...
# 8   申請 截止日 延長 至 年月日 止年 關渡 國際 自然 藝術 季 來自 真實 的 故事 徵求...
# 9   送養 報名 開始 囉 手邊 有犬貓 待 送 的 民眾 請 別錯過 了 ！ 報名 方式 請 詳...
# 10  進所 日期 年月日 捕獲 鄉鎮 市西 港區 東 竹林 近 後 營區 產業 道路 進所 原因 ...
# 11  我們 需要 台北 到 荷蘭 阿姆斯特丹 荷航 直飛 的 旅客 幫 我們 帶狗 。 文件 我們...
# 12  為 了 保育 場的 同伴 們 拼 了 ！ 寵物 展 還有 最後 一天 哦 協會 的 攤位 在...
# 13  劉邦 祺 說 ， 學校 師生 、 家長 常會 捐出 二手物品 ， 利用 校慶 或 其他 活動...
# 14  小浪童 寒夜 連鞋 都 沒有 唯一 寶貴 長袖 毛衣 讓給 夥伴 小黃狗 ️ 原來 ， 相依...
# 15  這周 末 ， 在 台 中 。 大人 、 小孩 一 起來 參與 海洋 影像 饗宴 。 ◆ 六 ...
# 16  尬 車哥 的 絡腮鬍 造型 ， 夠潮 吧 褓 姆 潮 男 ， 讓 小 的 幫 你 擦 嘴巴 ...
# 17  冰冰 聽得懂 自己 的 名字 耶 ！ 很 聰明 吧 ！ 小編 覺得 中途 麻好 用心 喔 ，...
# 18  原訂 日 下午 在 光點 舉辦 的 吉貓 認養 相親會 因 連日 低溫 下雨 的 天氣 考量...
# 19  好消息 與 越南 傳統 中藥 協會 簽訂 了 一個 重要 的 協議 ， 中藥 協會 承諾 將...
# 20  通報 人 送醫 檢查 了 目前 自行 照顧 若 需要 中途 幫忙 會 再 發文 嘉義 水上 ...
# 21  感恩 您 的 支持 與 肯定 讓 我們 有 能力 繼續 拯救 更 多 需要 幫助 的 毛孩子...
# 22  訂單 有 些許 出錯 無法 如期 收貨 的 朋友 不要 罵 得 太 用力 ～ 他們 會 很 ...
# 23  磨練 一個 人 的 耐性 ， 磨練 一個 人 的 孤獨 。 磨練 一個 人 的 恆心 ， 磨...
# 24  請 多 參考 認領 養 平台 上 資訊 想 知道 收容所 內有 哪些 毛 小孩 嗎 ？ 只要...
# 25  一張 照片 ， 想 帶來 什麼 ？ 是 一萬個 讚 ， 還是 一個 生命 的 改變 ？ 南 ...
# 26  ＊ 米克斯 ＊ 母 ＊ 皆 已 結紮 ＊ 目前 約 七個 月 大 個性 溫馴 親人 又 撒嬌...
# 27  請 大家 在 打 發票 時 ， 請 告訴 便利商店 店員 ， 我要 捐 愛心 碼 ， 照生 ...
# 28  住 在 的 ， 加油 啊 如果 你 還不 認識 ， 請 透過 狗 腳印 年桌 曆 與 她 相...
# 29  這 八個 孩子 這麼 小 就 被 帶進 收容所 ， 我們 不 知道 他們 的 媽媽 在 哪裡...
# 30  這 一次 的 案件 並 不是 車禍 ， 而是 傳染 率極 高 的 菜花 腫瘤 ， 照片 中 ...
# 31  編號 籠號 性別 男生 年紀 歲 花色 黃 虎 斑進 所 日期 收容 編號 原為 動保 案件...
# 32  又 去 找 美容師 挖 寶 黃金寶 送養 中項 錬 太小 條 ， 不 小心 就 會 被 毛 ...
# 33  寒冷 的 冬天 這些 流浪 動物 們 需要 您 的 幫忙 ！ ！ 台灣 貓狗 聯合 勸募 平...
# 34  適當 的 高度 ， 可 減少 貓咪 嘔吐 機會 ， 超 完美 碗 架 ， 多項 獨特 的 功...
# 35  貓桌 曆 貓咪 悄悄 說 ， 認養 爸媽 們 寫下 了 想 對貓 寶貝 說 的 悄悄話 ， ...
# 36  凡 購買 愛心 大使 張祖誠台 中場 演唱會 門票 一張 ， 浪浪 就 有 柏萊富 飼 天然...
# 37  小黑 是 典型 浪孩 的 悲歌 先 被遺棄 ， 再 被捕 獸 夾夾壞 腳 ， 又 差點 被 ...
# 38  搶救 六龜 斷腳 狗 及 小 孤兒 年月日 上午 ， 協會 救援隊 前往 高雄市 六龜 區 ...
# 39  來點 負 能量 減法 生活 瞭解 更 多 減法 生活 月 日 ， 南極 海洋生物 資源 養護...
# 40  為 了 捷運 新莊 機廠 開發 ， 樂生 院所 在 的 山坡 被 挖掉 了 一大半 一個 面...
# 41  經濟 民主 連合 研究員 許博任 經民連 在 就 曾經 發表聲明 ， 針對 輻射 食品 進口...
# 42  看似 平凡 的 材料 ， 經過 另外 一種 做法 就 會 有 耳目一新 的 感受 ， 白 肉...
# 43  零 核電 期間 ， 日本 進口 昂貴 的 液化 天然氣 量 創下 新高 ， 安倍 和 大多數...
# 44  年 夏季 北極 冰層 將 全部 融化 ， 失去 這天 然 空調 ， 地球 會 變成 什麼 樣...
# 45  朝日新聞 日本 原子力 規制 委員會 指示 東京 電力公司 停止 在 福島 核電廠 鎔 毀的...
# 46  對 台灣 偏鄉 的 弱勢 家庭 來說 ， 由於 就醫 不如 城市 方便 ， 加上 經濟 拮据...
# 47  迎接 年 前夕 ， 本會 再度 推出 年度 鉅 獻 十大 環境 新聞 ， 讓 所有 支持 環...
# 48  這期 的 季刊 文章 ， 環繞 著 一個 與 農友 、 消費者 都 切身 相關 的 主題 極...
# 49  人類 也 是 地球 物種 之一 ， 人類 當然 也 該 為 物種 消失 負起 責任 ， 追 ...
# 50  希望 多年 後 我們 看起來 也 像 濤 哥 一樣 永 。 保 。 年 。 輕健 ． 康 ．...
# 51  今天 早上 ， 我們 與 台灣 健康 空氣 行動 聯盟 的 夥伴 一起 到 總統府 前開 記...
# 52  屋頂 是 城市 的 另 一張 臉 。 從 空中 俯瞰 ， 台灣 都會區 的 屋頂 幾乎 都 ...
# 53  地震 後 ， 為 存放 受 輻射 汙染 的 地下水 ， 福島 第一 核電廠 開始 興建 密密...
# 54  內地 搖滾 活動 專賣 ， 為 台灣 加油 ！ 馬 上點 入 進行 募資 購票 小心 安全 ...
# 55  看到 了 生態 的 美好 ， 因而 想要 讓 更 多 人 看到 這樣 美好 的 景色 。 然...
# 56  你 曾經 深受 荒野 的 自然 講座 感動 嗎 ？ 那 一幅幅 動人 的 風景 、 有趣 的...

# %%
corpus = mergeData['docs'].values.tolist()

# %%
# TF-IDF
# coding:utf-8  
from sklearn.feature_extraction.text import CountVectorizer  
vectorizer = CountVectorizer()  
X = vectorizer.fit_transform(corpus)  
word = vectorizer.get_feature_names()  

from sklearn.feature_extraction.text import TfidfTransformer  
transformer = TfidfTransformer()  
tfidf = transformer.fit_transform(X)

# %%
len(corpus)
features = tfidf.toarray()
labels = mergeData['className'].values
labels
# Out:
# array(['"HOTAC', '"愛貓協會(NGO', 'APA中華民國保護動物協會', 'Rose的流浪動物花園',
#        'Taiwan SPCA 台灣防止虐待動物協會', 'g0v.tw 台灣零時政府', '古都保存再生文教基金會',
#        '台北鳥會野鳥救傷中心', '台北鳥會關渡自然公園管理處', '台南市關懷流浪動物協會',
#        '台灣公立收容所非官方認養資訊*the Unofficial Adoption info of Animal Shelter in Taiwan.*',
#        '台灣動物不再流浪協會', '台灣動物保護協進會', '台灣動物保護行政監督聯盟', '台灣動物平權促進會 TAEA',
#        '台灣動物社會研究會', '台灣愛兔協會', '台灣流浪兔保護協會', '台灣認養地圖 meetpets @Taiwan',
#        '台灣黑熊保育協會', '奶貓救援隊', '小卡貓狗救援志工團', '幸福狗流浪中途', '張媽媽流浪動物之家',
#        '彰化員林流浪犬收容所', '新竹流浪動物收容所照片公告區', '流浪狗不是廢棄物 不應由清潔隊捕捉(廢除安樂死)',
#        '照生會貓狗119', '狗腳印幸福聯盟 TPKR', '社團法人中華親善動物保護協會', '社團法人台南市流浪動物愛護協會',
#        '臺北市動物之家', '臺北市流浪貓保護協會-民間動保團體', '臺灣流浪動物認養 Home For Stray Taiwan',
#        '請支持流浪貓TNR計劃', '貓狗同樂會（台灣收容動物關懷協會）', '財團法人流浪動物之家基金會', '高雄市流浪動物保育協會',
#        '高雄市關懷流浪動物協會', 'Greenpeace 綠色和平 (台灣網站)',
#        'Wild at Heart Taiwan 台灣蠻野心足生態協會', '主婦聯盟環境保護基金會', '主婦聯盟生活消費合作社',
#        '全國廢核行動平台', '南台灣廢核行動聯盟', '反核部隊', '台灣世界展望會 World Vision Taiwan',
#        '台灣環境資訊協會 Taiwan Environmental Information Association (TEIA)',
#        '台灣農村陣線', '台灣農業讚', '善耕-關懷台灣文教基金會', '地球公民基金會', '媽媽監督核電廠聯盟',
#        '我是人，我反核！', '激進工作室 - Radicalization Studio', '環境資訊中心', '荒野保護協會'],
#       dtype=object)

# %%
# PCA
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
transData = pca.fit_transform(features, labels)
type(transData)
mergeData['pca1'] = DataFrame(transData[:,0])
mergeData['pca2'] = DataFrame(transData[:,1])
mergeData.head()
# Out:
#   docClass               className  \
# 0   animal                  "HOTAC
# 1   animal               "愛貓協會(NGO
# 2   animal           APA中華民國保護動物協會
# 3   animal             Rose的流浪動物花園
# 4   animal  Taiwan SPCA 台灣防止虐待動物協會
#
#                                                 docs      pca1      pca2
# 0  非常 直白 ， 非常 感慨 ， 也 讓 人 有 更深 的 省思 更 多 的 卻是 對 制度 ... -0.208130  0.284743
# 1  敬請 轉貼 歡迎 參觀 暫停 送養會 一次 ， 洽談 認養 及 預約 一般 日 晚上 時間 ... -0.228807 -0.296736
# 2  關心 流浪 動物 的 朋友 們 ， 最 擔心 的 就是 汪 喵 棄養 的 問題 ， 告訴您 ... -0.218734  0.043209
# 3  這是 一個 悲傷 的 故事 ， 我們 期待 它 有 個 溫暖 的 結局 兩隻 在 實驗室 過... -0.182264 -0.163372
# 4  剛才 沒有 看到 李奧納多 紀錄片 的 朋友 可以 到 這邊 線上 觀看 ！ 李奧納多 前往... -0.292749  0.391704

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(x_vars=['pca1'], y_vars=['pca2'], data=mergeData, hue="docClass", size=5)
# Out:
# /home/aesophor/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
textFrame = pd.DataFrame(features, columns = word)
textFrame.head()
len(features)
# Out:
# 57

# %%
allF = features.flatten()
nonZero = allF[np.nonzero(allF)]
m = np.median(nonZero)

# %%
allF[np.nonzero(allF)]
# Out:
# array([0.00205349, 0.00753411, 0.00078364, ..., 0.00166373, 0.00313949,
#        0.0004944 ])

# %%
plt.hist(nonZero, bins=500)
plt.show()
m
# Out:
# 0.000566379902350867

# %%
m = 0.1
dataset = list()
for i in range(len(features)):
    temp = textFrame.columns.values[[textFrame.iloc[i] >= m]]
    dataset.append(temp.tolist())
# Out:
# /home/aesophor/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   after removing the cwd from sys.path.

# %%
for i in range(len(features)):
    print(dataset[i])
# Out:
# ['下鄉', '之心', '動物', '可以', '台灣', '大家', '我們', '捐款', '支持', '活動', '活動中心', '流浪', '結紮', '絕育', '駐紮']
# ['動物', '協會', '愛貓', '收容所', '社團', '認養', '貓咪', '貓志工']
# ['中華民國', '保護', '八里', '動物', '勤美璞', '協會', '小犬', '我們', '林昆', '毛孩', '活動', '畫乙張', '畫作', '米克斯', '認養', '領我養']
# ['並先', '來訊', '儘快', '協會', '問卷', '回信', '回電', '填文', '幼犬', '我們', '狗狗', '白紙', '給你', '義工', '花園', '詳讀', '認養', '送養']
# ['動物', '協會', '可以', '台灣', '大家', '我們', '民眾', '狗狗', '虐待', '調查', '防止', '飼主']
# ['公民', '協作', '參與', '台灣', '專案', '政府', '社群', '科技', '議程', '資料', '開放', '開源', '零時', '黑客']
# ['保存', '古都', '台南', '基金會', '報名', '好務', '建築', '我們', '文化', '欣力', '歷史', '老屋', '老房子']
# ['中心', '傷鳥', '台北', '大家', '幼鳥', '我們', '救傷', '義工', '野鳥', '鳥兒', '鳥會', '鳥類']
# ['公園', '台北', '活動', '濕地', '管理處', '自然', '藝術', '野鳥', '關渡', '鳥會']
# ['代拍', '動物', '協會', '台南市', '善化', '收容所', '時分', '東昌', '流浪', '狗狗', '至時', '認養', '請轉', '謝謝', '走失', '關懷']
# ['不要', '公告', '分享', '動物', '孩子', '家裡', '希望', '收容所', '至時', '認養', '轉貼自', '遺照']
# ['不再', '動物', '協會', '台灣', '流浪', '結紮', '認養']
# ['保育', '保護', '動物', '協進會', '可以', '台灣', '孩子', '幫助', '愛心', '我們', '戶名', '捐款', '毛孩子', '筆記本', '絕育', '銀行']
# ['何宗勳', '保護', '動保', '動物', '協會', '台灣', '安樂死', '收容所', '校犬', '流浪', '生命', '行政監督', '關懷']
# ['促進會', '動平會', '動物', '台灣', '平權', '我們']
# ['動物', '台灣', '研究會', '社會', '神豬', '福利', '農委會']
# ['兔兔', '協會', '寵物', '愛兔', '捐款', '棄兔', '照顧', '自籌', '這群天']
# ['中途', '兔兔', '兔友', '助養', '協會', '台灣', '安置', '愛心', '捐款', '棄兔', '民權', '流浪', '浪兔', '申請書', '稅收', '立德', '認養', '金援']
# ['動物', '台灣', '地圖', '大家', '我們', '認養', '貓咪']
# ['保育', '動物', '協會', '台灣', '我們', '黑熊']
# ['動物', '可送', '外縣市', '奶媽', '奶貓', '小貓', '提供', '救援隊', '斷奶', '是否', '母貓', '物資', '週齡']
# ['三重', '助養', '動物', '協會', '台灣', '大家', '小卡', '小卡貓', '帳號', '志工團', '感恩', '我們', '戶名', '救援', '法人', '流浪', '社團', '觀音', '飼料']
# ['中途', '大家', '幸福', '愛媽', '流浪', '狗狗']
# ['之家張', '動物', '大家', '媽媽', '建國', '我們', '流浪', '花市', '認養']
# ['傳真號碼', '全日', '出早', '參觀', '員林', '導航', '巷直', '彰化', '彰化縣', '愛要', '收容所', '早帶', '每週', '每週五', '流浪', '犬貓會', '芬園', '衛星', '該址', '認養', '諮詢員', '鄉大彰', '開放', '領養']
# ['動物', '市縣', '收容所', '新竹縣', '時間', '晶片', '民眾', '滿歲', '竹北', '結紮', '認養', '證明文件', '身分', '開放', '領養']
# ['不應', '不是', '動物', '安樂死', '廢棄物', '廢除', '捕捉', '流浪狗', '清潔隊']
# ['台灣', '捐款', '照生', '首創']
# ['孩子', '局號', '帳號', '幸福', '我們', '捐款', '聯盟', '腳印', '郵局']
# ['中華', '五股', '保護', '動物', '協會', '場區', '大家', '孩子', '我們', '法人', '社團', '親善']
# ['協會', '古蹟', '台南市', '善款', '國定', '小組', '日治', '毛孩子', '研究', '編纂', '臺灣', '舊照']
# ['內湖區', '動物', '性別', '本區', '籠號', '美街號', '臺北市', '記住', '認養']
# ['保護', '動保', '協會', '可以', '團體', '民間', '流浪', '看貓', '臺北市', '認養', '貓咪', '送養', '需能', '養貓', '點免']
# ['動物', '流浪', '臺灣', '認養']
# ['元贈', '刷卡', '助罐', '匯款', '協會', '安養', '小額', '抵稅', '捐元贈', '捐款', '支持', '收據', '每筆', '流浪', '絕育', '網址', '街貓', '計劃', '認捐', '貓咪', '贈品', '贊助']
# ['中途', '動物', '同樂會', '寵物', '幼犬', '志工', '收容所', '活動', '狗狗', '臺北市', '認養', '貓狗', '貓狗桌']
# ['動物', '基金會', '小孩', '小組', '張祖', '我們', '救援', '朋友', '活動', '流浪', '財團法人']
# ['保育', '動物', '協會', '寵物', '我們', '毛孩子', '活動', '流浪', '義賣', '認養', '速寫', '飼料', '高雄市']
# ['助養', '動物', '匯款', '協助', '協會', '天使', '孩子', '幫助', '我們', '戶名', '毛孩子', '流浪', '買給', '關懷', '高雄市']
# ['一起', '全球', '再生能源', '北極', '和平', '守護', '我們', '殼牌', '海洋', '漁業', '環境', '綠色', '臺灣', '鑽油']
# ['協會', '台灣', '土地', '巨蛋', '律師', '我們', '政府', '環境', '環評', '生態', '蠻野', '野心', '開發']
# ['主婦', '台灣', '基改', '基金會', '我們', '環境', '環境保護', '綠繪本', '聯盟', '能源', '輻射', '食品', '食安', '食物', '食農']
# ['主婦', '台灣', '合作社', '基改', '我們', '消費', '生活', '生產者', '社員', '聯盟', '農友']
# ['全國', '反核', '台灣', '台電', '平台', '廢核', '我們', '核四', '核廢', '核廢料', '核災', '核能', '核電', '核電廠', '福島', '聯盟', '能源', '行動', '遊行']
# ['公民', '南台', '反核', '台灣', '台電', '廢核', '我們', '核四', '核廢料', '核電', '核電廠', '灣廢核', '聯盟', '能源', '行動', '遊行']
# ['反核', '台灣', '我們', '日本', '核反應', '核廢料', '核災', '核燃料', '核能', '核電', '核電廠', '福島', '輻射']
# ['三十', '世界', '兒童', '助學', '台灣', '孩子', '展望', '資助', '邀請', '飢餓']
# ['信託', '協會', '台灣', '地球', '我們', '活動', '海洋', '環境', '環資', '生態', '行動', '資訊']
# ['中途', '台灣', '徵收', '我們', '流浪狗', '狗狗', '農村', '農莊', '阿美']
# ['可以', '台灣', '土地', '小農', '我們', '有機', '種植', '自己', '農夫', '農業', '農民']
# ['偏鄉', '台灣', '善耕', '基金會', '孩子', '我們', '文教', '老師', '關懷']
# ['公民', '台灣', '地球', '基金會', '廢核', '後勁', '我們', '環境', '環評', '能源', '開發']
# ['再生能源', '台灣', '台電', '太陽能', '我們', '核四', '核廢料', '核災', '核電', '核電廠', '發電', '監督', '省電', '福島', '節能', '聯盟', '能源', '輻射']
# ['五六', '公民', '分享', '反核', '台灣', '台電', '大家', '廢核', '我們', '核四', '核電', '行動', '論壇', '運動']
# ['內地', '台灣', '工作室', '我們', '搖滾', '滅火器', '激進', '環保', '血肉']
# ['中斷', '台灣', '守護', '我們', '支持', '海編', '環境', '環資', '知情權', '羊編', '資訊', '需要']
# ['保護', '分會', '協會', '我們', '活動', '海洋', '淨灘', '環境', '荒野']

# %%
# Apriori: https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
graph = df.T
graph.columns = mergeData['className']

# %%
graph.head()
# Out:
# className  "HOTAC  "愛貓協會(NGO  APA中華民國保護動物協會  Rose的流浪動物花園  \
# 一起          False      False          False        False
# 三十          False      False          False        False
# 三重          False      False          False        False
# 下鄉           True      False          False        False
# 不再          False      False          False        False
#
# className  Taiwan SPCA 台灣防止虐待動物協會  g0v.tw 台灣零時政府  古都保存再生文教基金會  台北鳥會野鳥救傷中心  \
# 一起                          False          False        False       False
# 三十                          False          False        False       False
# 三重                          False          False        False       False
# 下鄉                          False          False        False       False
# 不再                          False          False        False       False
#
# className  台北鳥會關渡自然公園管理處  台南市關懷流浪動物協會   ...    \
# 一起                 False        False   ...
# 三十                 False        False   ...
# 三重                 False        False   ...
# 下鄉                 False        False   ...
# 不再                 False        False   ...
#
# className  台灣環境資訊協會 Taiwan Environmental Information Association (TEIA)  \
# 一起                                                     False
# 三十                                                     False
# 三重                                                     False
# 下鄉                                                     False
# 不再                                                     False
#
# className  台灣農村陣線  台灣農業讚  善耕-關懷台灣文教基金會  地球公民基金會  媽媽監督核電廠聯盟  我是人，我反核！  \
# 一起          False  False         False    False      False     False
# 三十          False  False         False    False      False     False
# 三重          False  False         False    False      False     False
# 下鄉          False  False         False    False      False     False
# 不再          False  False         False    False      False     False
#
# className  激進工作室 - Radicalization Studio  環境資訊中心  荒野保護協會
# 一起                                 False   False   False
# 三十                                 False   False   False
# 三重                                 False   False   False
# 下鄉                                 False   False   False
# 不再                                 False   False   False
#
# [5 rows x 57 columns]

# %%
from mlxtend.frequent_patterns import apriori

minsup = 0.01
apriori(graph, min_support = minsup, use_colnames=True)
# Out:
#       support                                           itemsets
# 0    0.038961                                           ("HOTAC)
# 1    0.020779                                        ("愛貓協會(NGO)
# 2    0.041558                                    (APA中華民國保護動物協會)
# 3    0.046753                                      (Rose的流浪動物花園)
# 4    0.031169                           (Taiwan SPCA 台灣防止虐待動物協會)
# 5    0.036364                                    (g0v.tw 台灣零時政府)
# 6    0.033766                                      (古都保存再生文教基金會)
# 7    0.031169                                       (台北鳥會野鳥救傷中心)
# 8    0.025974                                    (台北鳥會關渡自然公園管理處)
# 9    0.041558                                      (台南市關懷流浪動物協會)
# 10   0.031169  (台灣公立收容所非官方認養資訊*the Unofficial Adoption info o...
# 11   0.018182                                       (台灣動物不再流浪協會)
# 12   0.041558                                        (台灣動物保護協進會)
# 13   0.033766                                     (台灣動物保護行政監督聯盟)
# 14   0.015584                                   (台灣動物平權促進會 TAEA)
# 15   0.018182                                        (台灣動物社會研究會)
# 16   0.023377                                           (台灣愛兔協會)
# 17   0.046753                                        (台灣流浪兔保護協會)
# 18   0.018182                          (台灣認養地圖 meetpets @Taiwan)
# 19   0.015584                                         (台灣黑熊保育協會)
# 20   0.033766                                            (奶貓救援隊)
# 21   0.049351                                        (小卡貓狗救援志工團)
# 22   0.015584                                          (幸福狗流浪中途)
# 23   0.023377                                        (張媽媽流浪動物之家)
# 24   0.062338                                       (彰化員林流浪犬收容所)
# 25   0.038961                                   (新竹流浪動物收容所照片公告區)
# 26   0.023377                         (流浪狗不是廢棄物 不應由清潔隊捕捉(廢除安樂死))
# 27   0.010390                                         (照生會貓狗119)
# 28   0.023377                                     (狗腳印幸福聯盟 TPKR)
# 29   0.031169                                   (社團法人中華親善動物保護協會)
# ..        ...                                                ...
# 135  0.010390        (Taiwan SPCA 台灣防止虐待動物協會, "HOTAC, 小卡貓狗救援志工團)
# 136  0.010390       (台灣認養地圖 meetpets @Taiwan, 小卡貓狗救援志工團, "HOTAC)
# 137  0.010390                     (小卡貓狗救援志工團, "HOTAC, 張媽媽流浪動物之家)
# 138  0.010390               ("HOTAC, 財團法人流浪動物之家基金會, 高雄市流浪動物保育協會)
# 139  0.010390  (台灣認養地圖 meetpets @Taiwan, Taiwan SPCA 台灣防止虐待動物...
# 140  0.010390      (Taiwan SPCA 台灣防止虐待動物協會, 小卡貓狗救援志工團, 台灣黑熊保育協會)
# 141  0.010390  (Taiwan SPCA 台灣防止虐待動物協會, 社團法人中華親善動物保護協會, 小卡貓狗救...
# 142  0.010390             (台灣動物不再流浪協會, 台南市關懷流浪動物協會, 高雄市流浪動物保育協會)
# 143  0.010390           (高雄市關懷流浪動物協會, 台灣動物保護行政監督聯盟, 台南市關懷流浪動物協會)
# 144  0.010390              (小卡貓狗救援志工團, 台灣動物不再流浪協會, 台灣動物保護行政監督聯盟)
# 145  0.010390              (小卡貓狗救援志工團, 高雄市關懷流浪動物協會, 高雄市流浪動物保育協會)
# 146  0.010390                 (全國廢核行動平台, 南台灣廢核行動聯盟, 主婦聯盟環境保護基金會)
# 147  0.010390                 (媽媽監督核電廠聯盟, 全國廢核行動平台, 主婦聯盟環境保護基金會)
# 148  0.010390                (媽媽監督核電廠聯盟, 南台灣廢核行動聯盟, 主婦聯盟環境保護基金會)
# 149  0.015584                        (反核部隊, 全國廢核行動平台, 南台灣廢核行動聯盟)
# 150  0.010390                     (地球公民基金會, 全國廢核行動平台, 南台灣廢核行動聯盟)
# 151  0.023377                   (媽媽監督核電廠聯盟, 全國廢核行動平台, 南台灣廢核行動聯盟)
# 152  0.020779                    (我是人，我反核！, 全國廢核行動平台, 南台灣廢核行動聯盟)
# 153  0.018182                        (媽媽監督核電廠聯盟, 反核部隊, 全國廢核行動平台)
# 154  0.010390                         (我是人，我反核！, 反核部隊, 全國廢核行動平台)
# 155  0.012987                    (媽媽監督核電廠聯盟, 全國廢核行動平台, 我是人，我反核！)
# 156  0.012987                       (媽媽監督核電廠聯盟, 反核部隊, 南台灣廢核行動聯盟)
# 157  0.010390                        (我是人，我反核！, 反核部隊, 南台灣廢核行動聯盟)
# 158  0.010390                     (地球公民基金會, 南台灣廢核行動聯盟, 我是人，我反核！)
# 159  0.012987                   (我是人，我反核！, 媽媽監督核電廠聯盟, 南台灣廢核行動聯盟)
# 160  0.010390  (台灣認養地圖 meetpets @Taiwan, Taiwan SPCA 台灣防止虐待動物...
# 161  0.010390      (媽媽監督核電廠聯盟, 全國廢核行動平台, 南台灣廢核行動聯盟, 主婦聯盟環境保護基金會)
# 162  0.012987             (媽媽監督核電廠聯盟, 反核部隊, 全國廢核行動平台, 南台灣廢核行動聯盟)
# 163  0.010390              (我是人，我反核！, 反核部隊, 全國廢核行動平台, 南台灣廢核行動聯盟)
# 164  0.012987         (我是人，我反核！, 媽媽監督核電廠聯盟, 全國廢核行動平台, 南台灣廢核行動聯盟)
#
# [165 rows x 2 columns]

# %%
result = apriori(graph, min_support = minsup)
result
# Out:
#       support          itemsets
# 0    0.038961               (0)
# 1    0.020779               (1)
# 2    0.041558               (2)
# 3    0.046753               (3)
# 4    0.031169               (4)
# 5    0.036364               (5)
# 6    0.033766               (6)
# 7    0.031169               (7)
# 8    0.025974               (8)
# 9    0.041558               (9)
# 10   0.031169              (10)
# 11   0.018182              (11)
# 12   0.041558              (12)
# 13   0.033766              (13)
# 14   0.015584              (14)
# 15   0.018182              (15)
# 16   0.023377              (16)
# 17   0.046753              (17)
# 18   0.018182              (18)
# 19   0.015584              (19)
# 20   0.033766              (20)
# 21   0.049351              (21)
# 22   0.015584              (22)
# 23   0.023377              (23)
# 24   0.062338              (24)
# 25   0.038961              (25)
# 26   0.023377              (26)
# 27   0.010390              (27)
# 28   0.023377              (28)
# 29   0.031169              (29)
# ..        ...               ...
# 135  0.010390        (0, 4, 21)
# 136  0.010390       (0, 18, 21)
# 137  0.010390       (0, 21, 23)
# 138  0.010390       (0, 36, 37)
# 139  0.010390       (18, 4, 21)
# 140  0.010390       (19, 4, 21)
# 141  0.010390       (29, 4, 21)
# 142  0.010390       (9, 11, 37)
# 143  0.010390       (9, 13, 38)
# 144  0.010390      (21, 11, 13)
# 145  0.010390      (37, 21, 38)
# 146  0.010390      (41, 43, 44)
# 147  0.010390      (41, 43, 52)
# 148  0.010390      (41, 44, 52)
# 149  0.015584      (43, 44, 45)
# 150  0.010390      (51, 43, 44)
# 151  0.023377      (43, 44, 52)
# 152  0.020779      (43, 44, 53)
# 153  0.018182      (43, 52, 45)
# 154  0.010390      (53, 43, 45)
# 155  0.012987      (43, 52, 53)
# 156  0.012987      (44, 45, 52)
# 157  0.010390      (53, 44, 45)
# 158  0.010390      (51, 44, 53)
# 159  0.012987      (44, 53, 52)
# 160  0.010390    (0, 18, 4, 21)
# 161  0.010390  (41, 43, 44, 52)
# 162  0.012987  (43, 44, 45, 52)
# 163  0.010390  (53, 43, 44, 45)
# 164  0.012987  (43, 44, 53, 52)
#
# [165 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

rules = association_rules(result, metric="confidence", min_threshold=0.7)
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0        (44)        (43)            0.041558            0.049351  0.033766
# 1      (0, 4)        (12)            0.012987            0.041558  0.010390
# 2     (4, 12)         (0)            0.010390            0.038961  0.010390
# 3     (0, 18)         (4)            0.010390            0.031169  0.010390
# 4      (0, 4)        (18)            0.012987            0.018182  0.010390
#
#    confidence       lift  leverage  conviction
# 0      0.8125  16.463816  0.031715    5.070130
# 1      0.8000  19.250000  0.009850    4.792208
# 2      1.0000  25.666667  0.009985         inf
# 3      1.0000  32.083333  0.010066         inf
# 4      0.8000  44.000000  0.010153    4.909091

# %%
rules = association_rules(result, metric="lift", min_threshold=1.2)
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0         (0)         (4)            0.038961            0.031169  0.012987
# 1         (4)         (0)            0.031169            0.038961  0.012987
# 2         (0)        (11)            0.038961            0.018182  0.010390
# 3        (11)         (0)            0.018182            0.038961  0.010390
# 4         (0)        (12)            0.038961            0.041558  0.015584
#
#    confidence       lift  leverage  conviction
# 0    0.333333  10.694444  0.011773    1.453247
# 1    0.416667  10.694444  0.011773    1.647495
# 2    0.266667  14.666667  0.009681    1.338843
# 3    0.571429  14.666667  0.009681    2.242424
# 4    0.400000   9.625000  0.013965    1.597403

# %%
rules["antecedant_len"] = rules["antecedents"].apply(lambda x: len(x))
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0         (0)         (4)            0.038961            0.031169  0.012987
# 1         (4)         (0)            0.031169            0.038961  0.012987
# 2         (0)        (11)            0.038961            0.018182  0.010390
# 3        (11)         (0)            0.018182            0.038961  0.010390
# 4         (0)        (12)            0.038961            0.041558  0.015584
#
#    confidence       lift  leverage  conviction  antecedant_len
# 0    0.333333  10.694444  0.011773    1.453247               1
# 1    0.416667  10.694444  0.011773    1.647495               1
# 2    0.266667  14.666667  0.009681    1.338843               1
# 3    0.571429  14.666667  0.009681    2.242424               1
# 4    0.400000   9.625000  0.013965    1.597403               1

# %%
out = rules[ (rules['antecedant_len'] >= 2) &
       (rules['confidence'] > 0.75) &
       (rules['lift'] > 1.2) ]
out.head()
# Out:
#     antecedents consequents  antecedent support  consequent support  support  \
# 152      (0, 4)        (12)            0.012987            0.041558  0.01039
# 154     (4, 12)         (0)            0.010390            0.038961  0.01039
# 158     (0, 18)         (4)            0.010390            0.031169  0.01039
# 159      (0, 4)        (18)            0.012987            0.018182  0.01039
# 160     (18, 4)         (0)            0.010390            0.038961  0.01039
#
#      confidence       lift  leverage  conviction  antecedant_len
# 152         0.8  19.250000  0.009850    4.792208               2
# 154         1.0  25.666667  0.009985         inf               2
# 158         1.0  32.083333  0.010066         inf               2
# 159         0.8  44.000000  0.010153    4.909091               2
# 160         1.0  25.666667  0.009985         inf               2

# %%
support = rules['support']
confidence = rules['confidence']
plt.scatter(support, confidence, alpha=0.5, marker="*")
plt.xlabel('support')
plt.ylabel('confidence') 
plt.show()

# %%
len(rules)
rules['antecedents'].head()
# Out:
# 0     (0)
# 1     (4)
# 2     (0)
# 3    (11)
# 4     (0)
# Name: antecedents, dtype: object

# %%
import networkx as nx
G = nx.DiGraph()
for i in range(len(mergeData)):
    G.add_node(i)
for i in range(len(rules['antecedents'])):
    currentFrom = list(rules['antecedents'][i])
    currentTo = list(rules['consequents'][i])
    for j in range(len(currentFrom)):
        G.add_edge(currentFrom[j], currentTo[0])

# %%
nodeListA = mergeData.index[mergeData['docClass'] == 'animal'].tolist()
nodeListB = mergeData.index[mergeData['docClass'] == 'environment'].tolist()

plt.figure(figsize=(40,20))

# positions for all nodes
pos = nx.fruchterman_reingold_layout(G)

# nodes
nx.draw_networkx_nodes(G, pos, nodelist=nodeListA, node_color="b", node_size=1000)
nx.draw_networkx_nodes(G, pos, nodelist=nodeListB, node_color="g", node_size=1000)
nx.draw_networkx_edges(G, pos, width=6)

# labels
nx.draw_networkx_labels(G,pos,font_size=20,font_family='sans-serif')

plt.axis('off')
plt.savefig("weighted_graph.png") # save as png
plt.show() # display

# %%
# 獨立議題，和其他社團無關聯
list(nx.isolates(G))
# Out:
# [3, 5, 6, 7, 8, 14, 15, 20, 22, 26, 27, 28, 30, 31, 33, 39, 46, 48, 49, 50, 54]

# %%
# 小群體
from networkx.algorithms.approximation import dominating_set
dominating_set.min_edge_dominating_set(G)
# Out:
# {(0, 4),
#  (1, 9),
#  (2, 29),
#  (11, 13),
#  (12, 19),
#  (16, 17),
#  (18, 21),
#  (23, 37),
#  (24, 25),
#  (40, 47),
#  (41, 42),
#  (43, 44),
#  (45, 52),
#  (51, 53)}

# %%
pd.DataFrame(graph.columns)
# Out:
#                                             className
# 0                                              "HOTAC
# 1                                           "愛貓協會(NGO
# 2                                       APA中華民國保護動物協會
# 3                                         Rose的流浪動物花園
# 4                              Taiwan SPCA 台灣防止虐待動物協會
# 5                                       g0v.tw 台灣零時政府
# 6                                         古都保存再生文教基金會
# 7                                          台北鳥會野鳥救傷中心
# 8                                       台北鳥會關渡自然公園管理處
# 9                                         台南市關懷流浪動物協會
# 10  台灣公立收容所非官方認養資訊*the Unofficial Adoption info of...
# 11                                         台灣動物不再流浪協會
# 12                                          台灣動物保護協進會
# 13                                       台灣動物保護行政監督聯盟
# 14                                     台灣動物平權促進會 TAEA
# 15                                          台灣動物社會研究會
# 16                                             台灣愛兔協會
# 17                                          台灣流浪兔保護協會
# 18                            台灣認養地圖 meetpets @Taiwan
# 19                                           台灣黑熊保育協會
# 20                                              奶貓救援隊
# 21                                          小卡貓狗救援志工團
# 22                                            幸福狗流浪中途
# 23                                          張媽媽流浪動物之家
# 24                                         彰化員林流浪犬收容所
# 25                                     新竹流浪動物收容所照片公告區
# 26                           流浪狗不是廢棄物 不應由清潔隊捕捉(廢除安樂死)
# 27                                           照生會貓狗119
# 28                                       狗腳印幸福聯盟 TPKR
# 29                                     社團法人中華親善動物保護協會
# 30                                    社團法人台南市流浪動物愛護協會
# 31                                            臺北市動物之家
# 32                                  臺北市流浪貓保護協會-民間動保團體
# 33                     臺灣流浪動物認養 Home For Stray Taiwan
# 34                                        請支持流浪貓TNR計劃
# 35                                  貓狗同樂會（台灣收容動物關懷協會）
# 36                                      財團法人流浪動物之家基金會
# 37                                        高雄市流浪動物保育協會
# 38                                        高雄市關懷流浪動物協會
# 39                             Greenpeace 綠色和平 (台灣網站)
# 40                    Wild at Heart Taiwan 台灣蠻野心足生態協會
# 41                                        主婦聯盟環境保護基金會
# 42                                        主婦聯盟生活消費合作社
# 43                                           全國廢核行動平台
# 44                                          南台灣廢核行動聯盟
# 45                                               反核部隊
# 46                        台灣世界展望會 World Vision Taiwan
# 47  台灣環境資訊協會 Taiwan Environmental Information Asso...
# 48                                             台灣農村陣線
# 49                                              台灣農業讚
# 50                                       善耕-關懷台灣文教基金會
# 51                                            地球公民基金會
# 52                                          媽媽監督核電廠聯盟
# 53                                           我是人，我反核！
# 54                      激進工作室 - Radicalization Studio
# 55                                             環境資訊中心
# 56                                             荒野保護協會
